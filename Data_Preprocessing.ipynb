# %%
import pandas as pd

# %% [markdown]
# # Loading the Data

# %%
# Load the CSV files into DataFrames
temperature_anomalies = pd.read_csv("Data/annual-temperature-anomalies.csv")
monthly_surface_temp = pd.read_csv("Data/average-monthly-surface-temperature.csv")
co2_emissions = pd.read_csv("Data/co-emissions-per-capita.csv")
population = pd.read_csv("Data/population.csv")

# %%
temperature_anomalies.head()
# Out:
#         Entity Code  Year  Temperature anomaly
# 0  Afghanistan  AFG  1940            -1.202316
# 1  Afghanistan  AFG  1941             0.794745
# 2  Afghanistan  AFG  1942             0.355437
# 3  Afghanistan  AFG  1943            -1.005242
# 4  Afghanistan  AFG  1944            -0.386346

# %%
monthly_surface_temp.head()
# Out:
#         Entity Code  year         Day  Average monthly temperature  \
# 0  Afghanistan  AFG  1940  1940-01-15                    -2.032494
# 1  Afghanistan  AFG  1940  1940-02-15                    -0.733503
# 2  Afghanistan  AFG  1940  1940-03-15                     1.999134
# 3  Afghanistan  AFG  1940  1940-04-15                    10.199754
# 4  Afghanistan  AFG  1940  1940-05-15                    17.942135
#
#    Average annual temperature
# 0                   11.327695
# 1                   11.327695
# 2                   11.327695
# 3                   11.327695
# 4                   11.327695

# %%
monthly_surface_temp.rename(columns={"year": "Year"}, inplace=True)

# %%
co2_emissions.head()
# Out:
#         Entity Code  Year  Annual CO₂ emissions (per capita)
# 0  Afghanistan  AFG  1949                           0.001992
# 1  Afghanistan  AFG  1950                           0.010837
# 2  Afghanistan  AFG  1951                           0.011625
# 3  Afghanistan  AFG  1952                           0.011468
# 4  Afghanistan  AFG  1953                           0.013123

# %%
population.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1950
# 1  Afghanistan  AFG  1951
# 2  Afghanistan  AFG  1952
# 3  Afghanistan  AFG  1953
# 4  Afghanistan  AFG  1954
#
#    Population - Sex: all - Age: all - Variant: estimates
# 0                                            7776182
# 1                                            7879343
# 2                                            7987783
# 3                                            8096703
# 4                                            8207953

# %% [markdown]
# # Merge the Data

# %%
# First merge: Temperature anomalies with population
combined_df = pd.merge(temperature_anomalies, population, on=['Year', 'Code'], how='inner')

# Second merge: Add CO₂ emissions, specifying suffixes
combined_df = pd.merge(combined_df, co2_emissions, on=['Year', 'Code'], how='inner', suffixes=('', '_co2'))

# Third merge: Add monthly surface temperature, specifying suffixes
combined_df = pd.merge(combined_df, monthly_surface_temp, on=['Year', 'Code'], how='inner', suffixes=('', '_temp'))

# %%
combined_df.head()
# Out:
#       Entity_x Code  Year  Temperature anomaly     Entity_y  \
# 0  Afghanistan  AFG  1950            -2.298886  Afghanistan
# 1  Afghanistan  AFG  1950            -2.298886  Afghanistan
# 2  Afghanistan  AFG  1950            -2.298886  Afghanistan
# 3  Afghanistan  AFG  1950            -2.298886  Afghanistan
# 4  Afghanistan  AFG  1950            -2.298886  Afghanistan
#
#    Population - Sex: all - Age: all - Variant: estimates       Entity  \
# 0                                            7776182      Afghanistan
# 1                                            7776182      Afghanistan
# 2                                            7776182      Afghanistan
# 3                                            7776182      Afghanistan
# 4                                            7776182      Afghanistan
#
#    Annual CO₂ emissions (per capita)  Entity_temp         Day  \
# 0                           0.010837  Afghanistan  1950-01-15
# 1                           0.010837  Afghanistan  1950-02-15
# 2                           0.010837  Afghanistan  1950-03-15
# 3                           0.010837  Afghanistan  1950-04-15
# 4                           0.010837  Afghanistan  1950-05-15
#
#    Average monthly temperature  Average annual temperature
# 0                    -2.655707                   10.231125
# 1                    -3.996040                   10.231125
# 2                     3.491112                   10.231125
# 3                     8.332797                   10.231125
# 4                    17.329062                   10.231125

# %% [markdown]
# # Data Cleaning

# %%
columns_to_keep = [
    'Entity', 
    'Code', 
    'Year', 
    'Temperature anomaly', 
    'Population - Sex: all - Age: all - Variant: estimates', 
    'Annual CO₂ emissions (per capita)', 
    'Day', 
    'Average monthly temperature', 
    'Average annual temperature'
]

combined_df = combined_df[columns_to_keep]
combined_df.head()
# Out:
#         Entity Code  Year  Temperature anomaly  \
# 0  Afghanistan  AFG  1950            -2.298886
# 1  Afghanistan  AFG  1950            -2.298886
# 2  Afghanistan  AFG  1950            -2.298886
# 3  Afghanistan  AFG  1950            -2.298886
# 4  Afghanistan  AFG  1950            -2.298886
#
#    Population - Sex: all - Age: all - Variant: estimates  \
# 0                                            7776182
# 1                                            7776182
# 2                                            7776182
# 3                                            7776182
# 4                                            7776182
#
#    Annual CO₂ emissions (per capita)         Day  Average monthly temperature  \
# 0                           0.010837  1950-01-15                    -2.655707
# 1                           0.010837  1950-02-15                    -3.996040
# 2                           0.010837  1950-03-15                     3.491112
# 3                           0.010837  1950-04-15                     8.332797
# 4                           0.010837  1950-05-15                    17.329062
#
#    Average annual temperature
# 0                   10.231125
# 1                   10.231125
# 2                   10.231125
# 3                   10.231125
# 4                   10.231125

# %%
# change the data format
combined_df['Day'] = pd.to_datetime(combined_df['Day'])
combined_df.head()
# Out:
#         Entity Code  Year  Temperature anomaly  \
# 0  Afghanistan  AFG  1950            -2.298886
# 1  Afghanistan  AFG  1950            -2.298886
# 2  Afghanistan  AFG  1950            -2.298886
# 3  Afghanistan  AFG  1950            -2.298886
# 4  Afghanistan  AFG  1950            -2.298886
#
#    Population - Sex: all - Age: all - Variant: estimates  \
# 0                                            7776182
# 1                                            7776182
# 2                                            7776182
# 3                                            7776182
# 4                                            7776182
#
#    Annual CO₂ emissions (per capita)        Day  Average monthly temperature  \
# 0                           0.010837 1950-01-15                    -2.655707
# 1                           0.010837 1950-02-15                    -3.996040
# 2                           0.010837 1950-03-15                     3.491112
# 3                           0.010837 1950-04-15                     8.332797
# 4                           0.010837 1950-05-15                    17.329062
#
#    Average annual temperature
# 0                   10.231125
# 1                   10.231125
# 2                   10.231125
# 3                   10.231125
# 4                   10.231125

# %%
# Check for missing values
combined_df.isnull().sum()
# Out:
# Entity                                                   0
# Code                                                     0
# Year                                                     0
# Temperature anomaly                                      0
# Population - Sex: all - Age: all - Variant: estimates    0
# Annual CO₂ emissions (per capita)                        0
# Day                                                      0
# Average monthly temperature                              0
# Average annual temperature                               0
# dtype: int64

# %%
combined_df.duplicated().sum()
# Out:
# 0

# %%
# Reshaping the DataFrame for Tableau
reshaped_df = combined_df.melt(
    id_vars=['Year'], 
    value_vars=['Annual CO₂ emissions (per capita)', 'Temperature anomaly', 'Population - Sex: all - Age: all - Variant: estimates'], 
    var_name='Metric', 
    value_name='Value'
)

# Save reshaped DataFrame for Tableau
reshaped_df.to_csv('reshaped_combined_df.csv', index=False)

# %%
reshaped_df.head()
# Out:
#    Year                             Metric     Value
# 0  1950  Annual CO₂ emissions (per capita)  0.010837
# 1  1950  Annual CO₂ emissions (per capita)  0.010837
# 2  1950  Annual CO₂ emissions (per capita)  0.010837
# 3  1950  Annual CO₂ emissions (per capita)  0.010837
# 4  1950  Annual CO₂ emissions (per capita)  0.010837

# %% [markdown]
# # Output the Cleaned Dataframe

# %%
combined_df.to_csv('cleaned_data.csv', index=False)
